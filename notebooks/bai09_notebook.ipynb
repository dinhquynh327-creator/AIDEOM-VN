# %% [markdown]
# # Bài 9 - Mô phỏng lao động AI
# Trong notebook này, chúng ta sẽ thực thi logic tối ưu / phân tích được định nghĩa trong mã nguồn `src/`.
# Cách tổ chức này giúp mã nguồn được tái sử dụng (reusable) ở cả Dashboard và Notebook.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from src.optimization import solve_bai09

# Chạy thử mô hình với tham số mặc định
result = solve_bai09()

# Hiển thị kết quả
for k, v in result.items():
    print(f"{k}: {v}")
